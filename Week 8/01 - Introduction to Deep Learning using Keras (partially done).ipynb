# %% [markdown]
# This exercise is adapted from https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/
#
#
# ## Keras Tutorial Overview
#
# There is not a lot of code required, but we are going to step over it slowly so that you will know how to create your own models in the future.
#
# The steps you are going to cover in this tutorial are as follows:
#
# 1. Load Data.
# 2. Define Keras Model.
# 3. Compile Keras Model.
# 4. Fit Keras Model.
# 5. Evaluate Keras Model.
# 6. Tie It All Together.
# 7. Make Predictions
#
# This Keras tutorial has a few requirements:
#
# 1. You have Python 2 or 3 installed and configured.
# 2. You have SciPy (including NumPy) installed and configured.
# 3. You have Keras and a backend (Theano or TensorFlow) installed and configured.

# %% [markdown]
# ### 1. Load Data
# The first step is to define the functions and classes we intend to use in this tutorial.
#
# We will use the NumPy library to load our dataset and we will use two classes from the Keras library to define our model.
#
# The imports required are listed below.

# %%
# first neural network with keras tutorial
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense


import seaborn as sns

sns.set()

# %% [markdown]
# Now load the data from *file pima-indians-diabetes.data.csv* stored in Data folder (check Google Drive if unsure)

# %%
# load the dataset
dataset = loadtxt('..\data\pima-indians-diabetes.data.csv', delimiter=',')

# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %% [markdown]
# **Q:** Find out more about the dataset - such as how many columns, what kind of information does it provide etc.

# %%
import pandas as pd

df = pd.DataFrame(data=dataset)
# df.head()
df.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#                 6           7           8
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# 50%      0.372500   29.000000    0.000000
# 75%      0.626250   41.000000    1.000000
# max      2.420000   81.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       768 non-null    float64
#  1   1       768 non-null    float64
#  2   2       768 non-null    float64
#  3   3       768 non-null    float64
#  4   4       768 non-null    float64
#  5   5       768 non-null    float64
#  6   6       768 non-null    float64
#  7   7       768 non-null    float64
#  8   8       768 non-null    float64
# dtypes: float64(9)
# memory usage: 54.1 KB

# %% [markdown]
# ### 2. Define Keras Model
# Models in Keras are defined as a sequence of layers.
#
# We create a **Sequential model** and add layers one at a time until we are happy with our network architecture.
#
# The first thing to get right is to ensure the input layer has the right number of input features. This can be specified when creating the first layer with the **input_dim** argument and setting it to 8 for the 8 input variables.
#
# *Question:* How do we know the number of layers and their types?
#
# This is a very hard question. There are heuristics that we can use and often the best network structure is found through a process of trial and error experimentation (I explain more about this here). Generally, you need a network large enough to capture the structure of the problem.
#
# In this example, we will use a fully-connected network structure with three layers.
#
# Fully connected layers are defined using the Dense class. We can specify the number of neurons or nodes in the layer as the first argument, and specify the activation function using the activation argument.
#
# We will use the rectified linear unit activation function referred to as ReLU on the first two layers and the Sigmoid function in the output layer.
#
# It used to be the case that Sigmoid and Tanh activation functions were preferred for all layers. These days, better performance is achieved using the ReLU activation function. We use a sigmoid on the output layer to ensure our network output is between 0 and 1 and easy to map to either a probability of class 1 or snap to a hard classification of either class with a default threshold of 0.5.
#
# We can piece it all together by adding each layer:
#
# * The model expects rows of data with 8 variables (the input_dim=8 argument)
# * The first hidden layer has 12 nodes and uses the relu activation function.
# * The second hidden layer has 8 nodes and uses the relu activation function.
# * The output layer has one node and uses the sigmoid activation function.

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### 3. Compile Keras Model
# Now that the model is defined, we can compile it.
#
# Compiling the model uses the efficient numerical libraries under the covers (the so-called backend) such as Theano or TensorFlow. The backend automatically chooses the best way to represent the network for training and making predictions to run on your hardware, such as CPU or GPU or even distributed.
#
# When compiling, we must specify some additional properties required when training the network. Remember training a network means finding the best set of weights to map inputs to outputs in our dataset.
#
# We must specify the loss function to use to evaluate a set of weights, the optimizer is used to search through different weights for the network and any optional metrics we would like to collect and report during training.
#
# In this case, we will use cross entropy as the **loss** argument. This loss is for a binary classification problems and is defined in Keras as **“binary_crossentropy“**.
#
# We will define the optimizer as the efficient stochastic gradient descent algorithm “adam“. This is a popular version of gradient descent because it automatically tunes itself and gives good results in a wide range of problems.
#
# Finally, because it is a classification problem, we will collect and report the classification accuracy, defined via the metrics argument.

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### 4. Fit Keras Model
# We have defined our model and compiled it ready for efficient computation.
#
# Now it is time to execute the model on some data.
#
# We can train or fit our model on our loaded data by calling the fit() function on the model.
#
# Training occurs over epochs and each epoch is split into batches.
#
# * **Epoch:** One pass through all of the rows in the training dataset.
# * **Batch:** One or more samples considered by the model within an epoch before weights are updated.
#
# One epoch is comprised of one or more batches, based on the chosen batch size and the model is fit for many epochs.
#
# The training process will run for a fixed number of iterations through the dataset called epochs, that we must specify using the epochs argument. We must also set the number of dataset rows that are considered before the model weights are updated within each epoch, called the batch size and set using the batch_size argument.
#
# For this problem, we will run for a small number of epochs (150) and use a relatively small batch size of 10.
#
# These configurations can be chosen experimentally by trial and error. We want to train the model enough so that it learns a good (or good enough) mapping of rows of input data to the output classification. The model will always have some error, but the amount of error will level out after some point for a given model configuration. This is called model convergence.

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 2ms/step - loss: 4.9996 - accuracy: 0.6536
# Epoch 2/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.1076 - accuracy: 0.6133
# Epoch 3/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.8039 - accuracy: 0.5859
# Epoch 4/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7569 - accuracy: 0.6094
# Epoch 5/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7231 - accuracy: 0.6055
# Epoch 6/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7220 - accuracy: 0.6159
# Epoch 7/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6866 - accuracy: 0.6302
# Epoch 8/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6705 - accuracy: 0.6393
# Epoch 9/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6448 - accuracy: 0.6615
# Epoch 10/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6379 - accuracy: 0.6484
# Epoch 11/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6360 - accuracy: 0.6523
# Epoch 12/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6286 - accuracy: 0.6328
# Epoch 13/150
# 77/77 [==============================] - 0s 980us/step - loss: 0.6229 - accuracy: 0.6628
# Epoch 14/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6128 - accuracy: 0.6602
# Epoch 15/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6120 - accuracy: 0.6667
# Epoch 16/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6065 - accuracy: 0.6549
# Epoch 17/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6000 - accuracy: 0.6823
# Epoch 18/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6082 - accuracy: 0.6589
# Epoch 19/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6039 - accuracy: 0.6719
# Epoch 20/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6013 - accuracy: 0.6810
# Epoch 21/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5931 - accuracy: 0.6693
# Epoch 22/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5839 - accuracy: 0.6810
# Epoch 23/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5919 - accuracy: 0.6927
# Epoch 24/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5912 - accuracy: 0.6849
# Epoch 25/150
# 77/77 [==============================] - 0s 943us/step - loss: 0.5866 - accuracy: 0.6784
# Epoch 26/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5858 - accuracy: 0
150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4751 - accuracy: 0.7682
# Epoch 141/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4872 - accuracy: 0.7552
# Epoch 142/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4759 - accuracy: 0.7734
# Epoch 143/150
# 77/77 [==============================] - 0s 984us/step - loss: 0.4862 - accuracy: 0.7708
# Epoch 144/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4791 - accuracy: 0.7669
# Epoch 145/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4722 - accuracy: 0.7760
# Epoch 146/150
# 77/77 [==============================] - 0s 899us/step - loss: 0.4740 - accuracy: 0.7721
# Epoch 147/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4744 - accuracy: 0.7695
# Epoch 148/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4729 - accuracy: 0.7695
# Epoch 149/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4699 - accuracy: 0.7786
# Epoch 150/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4730 - accuracy: 0.7799

# %% [markdown]
# **Q:** change the value of Epoch - what differences will you expect/see?

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=300, batch_size=30)
# Out:
# Epoch 1/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4583 - accuracy: 0.7773
# Epoch 2/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4620 - accuracy: 0.7852
# Epoch 3/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4585 - accuracy: 0.7839
# Epoch 4/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4584 - accuracy: 0.7773
# Epoch 5/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4584 - accuracy: 0.7826
# Epoch 6/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4593 - accuracy: 0.7695
# Epoch 7/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4551 - accuracy: 0.7826
# Epoch 8/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4572 - accuracy: 0.7721
# Epoch 9/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4579 - accuracy: 0.7760
# Epoch 10/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4575 - accuracy: 0.7799
# Epoch 11/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4584 - accuracy: 0.7773
# Epoch 12/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4568 - accuracy: 0.7812
# Epoch 13/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4563 - accuracy: 0.7799
# Epoch 14/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4563 - accuracy: 0.7826
# Epoch 15/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4592 - accuracy: 0.7747
# Epoch 16/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4583 - accuracy: 0.7734
# Epoch 17/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4597 - accuracy: 0.7682
# Epoch 18/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4560 - accuracy: 0.7734
# Epoch 19/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4543 - accuracy: 0.7760
# Epoch 20/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4573 - accuracy: 0.7826
# Epoch 21/300
# 26/26 [==============================] - 0s 999us/step - loss: 0.4576 - accuracy: 0.7826
# Epoch 22/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4533 - accuracy: 0.7773
# Epoch 23/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4556 - accuracy: 0.7812
# Epoch 24/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4555 - accuracy: 0.7760
# Epoch 25/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4533 - accuracy: 0.7760
# Epoch 26/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4556 - accuracy: 0.7721
# Epoch 27/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4592 - accuracy: 0.7734
# Epoch 28/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4532 - accuracy: 0.7786
# Epoch 29/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4530 - accuracy: 0.7799
# Epoch 30/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4544 - accuracy: 0.7773
# Epoch 31/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4529 - accuracy: 0.7760
# Epoch 32/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7747
# Epoch 33/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4541 - accuracy: 0.7760
# Epoch 34/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4539 - accuracy: 0.7812
# Epoch 35/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4575 - accuracy: 0.7773
# Epoch 36/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4524 - accuracy: 0.7812
# Epoch 37/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4526 - accuracy: 0.7799
# Epoch 38/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4545 - accuracy: 0.7799
# Epoch 39/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4530 - accuracy: 0.7786
# Epoch 40/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4577 - accuracy: 0.7747
# Epoch 41/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4500 - accuracy: 0.7826
# Epoch 42/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4526 - accuracy: 0.7799
# Epoch 43/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4566 - accuracy: 0.7878
# Epoch 44/300
# 26/26 [==============================] - 0s 924us/step - loss: 0.4653 - accuracy: 0.7721
# Epoch 45/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4503 - accuracy: 0.7826
# Epoch 46/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4586 - accuracy: 0.7826
# Epoch 47/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4513 - accuracy: 0.7839
# Epoch 48/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4583 - accuracy: 0.7826
# Epoch 49/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4539 - accuracy: 0.7786
# Epoch 50/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4592 - accuracy: 0.7773
# Epoch 51/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4615 - accuracy: 0.7695
# Epoch 52/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4547 - accuracy: 0.7839
# Epoch 53/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4536 - accuracy: 0.7839
# Epoch 54/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4697 - accuracy: 0.7656
# Epoch 55/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4612 - accuracy: 0.7747
# Epoch 56/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4495 - accuracy: 0.7760
# Epoch 57/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4525 - accuracy: 0.7826
# Epoch 58/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4540 - accuracy: 0.7734
# Epoch 59/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4539 - accuracy: 0.7786
# Epoch 60/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4517 - accuracy: 0.7865
# Epoch 61/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4538 - accuracy: 0.7747
# Epoch 62/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4521 - accuracy: 0.7852
# Epoch 63/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4518 - accuracy: 0.7734
# Epoch 64/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4518 - accuracy: 0.7799
# Epoch 65/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4509 - accuracy: 0.7786
# Epoch 66/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4512 - accuracy: 0.7786
# Epoch 67/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4546 - accuracy: 0.7747
# Epoch 68/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4502 - accuracy: 0.7839
# Epoch 69/300
# 26/26 [==============================] - 0s 880us/step - loss: 0.4505 - accuracy: 0.7760
# Epoch 70/300
# 26/26 [==============================] - 0s 982us/step - loss: 0.4527 - accuracy: 0.7747
# Epoch 71/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4538 - accuracy: 0.7760
# Epoch 72/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4489 - accuracy: 0.7786
# Epoch 73/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4554 - accuracy: 0.7799
# Epoch 74/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4582 - accuracy: 0.7734
# Epoch 75/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4522 - accuracy: 0.7773
# Epoch 76/300
# 26/26 [==============================] - 0s 905us/step - loss: 0.4529 - accuracy: 0.7826
# Epoch 77/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4514 - accuracy: 0.7799
# Epoch 78/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4509 - accuracy: 0.7799
# Epoch 79/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4490 - accuracy: 0.7826
# Epoch 80/300
# 26/26 [==============================] - 0s 877us/step - loss: 0.4530 - accuracy: 0.7773
# Epoch 81/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4528 - accuracy: 0.7812
# Epoch 82/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4586 - accuracy: 0.7773
# Epoch 83/300
# 26/26 [==============================] - 0s 868us/step - loss: 0.4466 - accuracy: 0.7786
# Epoch 84/300
# 26/26 [==============================] - 0s 866us/step - loss: 0.4470 - accuracy: 0.7812
# Epoch 85/300
# 26/26 [==============================] - 0s 760us/step - loss: 0.4552 - accuracy: 0.7734
# Epoch 86/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4485 - accuracy: 0.
300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4282 - accuracy: 0.7956
# Epoch 297/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4318 - accuracy: 0.7943
# Epoch 298/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4263 - accuracy: 0.7943
# Epoch 299/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4262 - accuracy: 0.8086
# Epoch 300/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4333 - accuracy: 0.7878

# %% [markdown]
# ### 5. Evaluate Keras Model
# We have trained our neural network on the entire dataset and we can evaluate the performance of the network on the same dataset.
#
# This will only give us an idea of how well we have modeled the dataset (e.g. train accuracy), but no idea of how well the algorithm might perform on new data. We have done this for simplicity, but ideally, you could separate your data into train and test datasets for training and evaluation of your model.
#
# You can evaluate your model on your training dataset using the **evaluate()** function on your model and pass it the same input and output used to train the model.
#
# This will generate a prediction for each input and output pair and collect scores, including the average loss and any metrics you have configured, such as accuracy.
#
# The **evaluate()** function will return a list with two values. The first will be the loss of the model on the dataset and the second will be the accuracy of the model on the dataset. We are only interested in reporting the accuracy, so we will ignore the loss value.

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4260 - accuracy: 0.7969
# Accuracy: 79.69

# %% [markdown]
# ### 7. Make Predictions
# We can adapt the above example and use it to generate predictions on the training dataset, pretending it is a new dataset we have not seen before.
#
# Making predictions is as easy as calling the predict() function on the model. We are using a sigmoid activation function on the output layer, so the predictions will be a probability in the range between 0 and 1. We can easily convert them into a crisp binary prediction for this classification task by rounding them.

# %%
# make probability predictions with the model
predictions = model.predict(X)

# round predictions 
rounded = [round(x[0]) for x in predictions]

# %% [markdown]
# **Q:** now redo predictions by using the function predict_classes(). Show the outcome of the first 10 cases (code provided)

# %%
import numpy as np
classes_x=np.argmax(predictions,axis=1)

for i in range(10):
    print('%s => %d (expected %d)' % (X[i].tolist(), classes_x[i], y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 0 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 0 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 0 (expected 1)
# [5.0, 116.0, 74.0, 0.0, 0.0, 25.6, 0.201, 30.0] => 0 (expected 0)
# [3.0, 78.0, 50.0, 32.0, 88.0, 31.0, 0.248, 26.0] => 0 (expected 1)
# [10.0, 115.0, 0.0, 0.0, 0.0, 35.3, 0.134, 29.0] => 0 (expected 0)
# [2.0, 197.0, 70.0, 45.0, 543.0, 30.5, 0.158, 53.0] => 0 (expected 1)
# [8.0, 125.0, 96.0, 0.0, 0.0, 0.0, 0.232, 54.0] => 0 (expected 1)

# %% [markdown]
# ## Challenge 1:
# Separate the training and test datasets (70% vs 30%) and rerun the evaluation

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y, test_size=0.3)
model.fit(x_test, y_test, epochs=150, batch_size=10)
_, accuracy = model.evaluate(x_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4324 - accuracy: 0.7879
# Epoch 2/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4233 - accuracy: 0.7922
# Epoch 3/150
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4287 - accuracy: 0.8095
# Epoch 4/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4444 - accuracy: 0.7835
# Epoch 5/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4633 - accuracy: 0.7619
# Epoch 6/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4141 - accuracy: 0.8052
# Epoch 7/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4146 - accuracy: 0.7965
# Epoch 8/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4130 - accuracy: 0.7879
# Epoch 9/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4659 - accuracy: 0.7706
# Epoch 10/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4332 - accuracy: 0.7749
# Epoch 11/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4212 - accuracy: 0.8182
# Epoch 12/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4393 - accuracy: 0.7576
# Epoch 13/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4166 - accuracy: 0.7922
# Epoch 14/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4118 - accuracy: 0.7835
# Epoch 15/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4179 - accuracy: 0.7879
# Epoch 16/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4121 - accuracy: 0.7835
# Epoch 17/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4109 - accuracy: 0.8009
# Epoch 18/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4037 - accuracy: 0.8009
# Epoch 19/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4161 - accuracy: 0.7965
# Epoch 20/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4334 - accuracy: 0.7749
# Epoch 21/150
# 24/24 [==============================] - 0s 984us/step - loss: 0.4190 - accuracy: 0.7965
# Epoch 22/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4053 - accuracy: 0.8009
# Epoch 23/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4036 - accuracy: 0.8009
# Epoch 24/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4006 - accuracy: 0.8009
# Epoch 25/150
# 24/24 [==============================] - 0s 993us/step - loss: 0.4174 - accuracy: 0.7965
# Epoch 26/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4133 - accuracy: 0.8268
# Epoch 27/150
# 24/24 [==============================] - 0s 956us/step - loss: 0.4081 - accuracy: 0.7922
# Epoch 28/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4975 - accuracy: 0.7619
# Epoch 29/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4709 - accuracy: 0.7749
# Epoch 30/150
# 24/24 [==============================] - 0s 921us/step - loss: 0.4322 - accuracy: 0.7965
# Epoch 31/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4448 - accuracy: 0.7835
# Epoch 32/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4250 - accuracy: 0.8182
# Epoch 33/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4007 - accuracy: 0.8095
# Epoch 34/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3918 - accuracy: 0.8139
# Epoch 35/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3920 - accuracy: 0.8182
# Epoch 36/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.8268
# Epoch 37/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3939 - accuracy: 0.8182
# Epoch 38/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4041 - accuracy: 0.8095
# Epoch 39/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4008 - accuracy: 0.8268
# Epoch 40/150
# 24/24 [==============================] - 0s 962us/step - loss: 0.3949 - accuracy: 0.8095
# Epoch 41/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3929 - accuracy: 0.8268
# Epoch 42/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4267 - accuracy: 0.7965
# Epoch 43/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4023 - accuracy: 0.8225
# Epoch 44/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4032 - accuracy: 0.8139
# Epoch 45/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4656 - accuracy: 0.7879
# Epoch 46/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4064 - accuracy: 0.8139
# Epoch 47/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4061 - accuracy: 0.8009
# Epoch 48/150
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4037 - accuracy: 0.8182
# Epoch 49/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3957 - accuracy: 0.8225
# Epoch 50/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4100 - accuracy: 0.7965
# Epoch 51/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3946 - accuracy: 0.8268
# Epoch 52/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4044 - accuracy: 0.8095
# Epoch 53/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4155 - accuracy: 0.8225
# Epoch 54/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4016 - accuracy: 0.7965
# Epoch 55/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4059 - accuracy: 0.8095
# Epoch 56/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3886 - accuracy: 0.8312
# Epoch 57/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3835 - accuracy: 0.8442
# Epoch 58/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3894 - accuracy: 0.8268
# Epoch 59/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3973 - accuracy: 0.8182
# Epoch 60/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3877 - accuracy: 0.8268
# Epoch 61/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3994 - accuracy: 0.8182
# Epoch 62/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3979 - accuracy: 0.8139
# Epoch 63/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3829 - accuracy: 0.8312
# Epoch 64/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3842 - accuracy: 0.8312
# Epoch 65/150
# 24/24 [==============================] - 0s 915us/step - loss: 0.3802 - accuracy: 0.8225
# Epoch 66/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3839 - accuracy: 0.8268
# Epoch 67/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3793 - accuracy: 0.8485
# Epoch 68/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3798 - accuracy: 0.8355
# Epoch 69/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3819 - accuracy: 0.8398
# Epoch 70/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3795 - accuracy: 0.8268
# Epoch 71/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3789 - accuracy: 0.8312
# Epoch 72/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3864 - accuracy: 0.8268
# Epoch 73/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3904 - accuracy: 0.8355
# Epoch 74/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4068 - accuracy: 0.8139
# Epoch 75/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3830 - accuracy: 0.8485
# Epoch 76/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3756 - accuracy: 0.8485
# Epoch 77/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3942 - accuracy: 0.8009
# Epoch 78/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3894 - accuracy: 0.8225
# Epoch 79/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3845 - accuracy: 0.8225
# Epoch 80/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3753 - accuracy: 0.8398
# Epoch 81/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3728 - accuracy: 0.8312
# Epoch 82/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3761 - accuracy: 0.8398
# Epoch 83/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3862 - accuracy: 0.8095
# Epoch 84/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3747 - accuracy: 0.8312
# Epoch 85/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3783 - accuracy: 0.8225
# Epoch 86/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3708 - accuracy: 0.8355
# Epoch 87/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3872 - accuracy: 0.8182
# Epoch 88/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3804 - accuracy: 0.8225
# Epoch 89/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3816 - accuracy: 0.8268
# Epoch 90/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3729 - accuracy: 0.8182
# Epoch 91/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3874 - accuracy: 0.8139
# Epoch 92/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3775 - accuracy: 0.8442
# Epoch 93/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3767 - accuracy: 0.8225
# Epoch 94/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3855 - accuracy: 0.8139
# Epoch 95/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3876 - accuracy: 0.8139
# Epoch 96/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3856 - accuracy: 0.8139
# Epoch 97/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3759 - accuracy: 0.8312
# Epoch 98/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3711 - accuracy: 0.8485
# Epoch 99/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3688 - accuracy: 0.8398
# Epoch 100/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8268
# Epoch 101/150
# 24/24 [==============================] - 0s 864us/step - loss: 0.3796 - accuracy: 0.8095
# Epoch 102/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4261 - accuracy: 0.8182
# Epoch 103/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3939 - accuracy: 0.8268
# Epoch 104/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3742 - accuracy: 0.8139
# Epoch 105/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3732 - accuracy: 0.8398
# Epoch 106/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3808 - accuracy: 0.8139
# Epoch 107/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3681 - accuracy: 0.8442
# Epoch 108/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3644 - accuracy: 0.8615
# Epoch 109/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4111 - accuracy: 0.7922
# Epoch 110/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3787 - accuracy: 0.8442
# Epoch 111/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3803 - accuracy: 0.8268
# Epoch 112/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3878 - accuracy: 0.8052
# Epoch 113/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3794 - accuracy: 0.8442
# Epoch 114/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4057 - accuracy: 0.8052
# Epoch 115/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3722 - accuracy: 0.8442
# Epoch 116/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3644 - accuracy: 0.8571
# Epoch 117/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3717 - accuracy: 0.8182
# Epoch 118/150
# 24/24 [==============================] - 0s 900us/step - loss: 0.3702 - accuracy: 0.8398
# Epoch 119/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3641 - accuracy: 0.8398
# Epoch 120/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3627 - accuracy: 0.8398
# Epoch 121/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3832 - accuracy: 0.8312
# Epoch 122/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3697 - accuracy: 0.8442
# Epoch 123/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3637 - accuracy: 0.8355
# Epoch 124/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3650 - accuracy: 0.8355
# Epoch 125/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3640 - accuracy: 0.8485
# Epoch 126/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3635 - accuracy: 0.8355
# Epoch 127/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3662 - accuracy: 0.8485
# Epoch 128/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4413 - accuracy: 0.8009
# Epoch 129/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4017 - accuracy: 0.8095
# Epoch 130/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3882 - accuracy: 0.8225
# Epoch 131/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3892 - accuracy: 0.8225
# Epoch 132/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3794 - accuracy: 0.8225
# Epoch 133/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4248 - accuracy: 0.8052
# Epoch 134/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4059 - accuracy: 0.8009
# Epoch 135/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3838 - accuracy: 0.8095
# Epoch 136/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3732 - accuracy: 0.8225
# Epoch 137/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3656 - accuracy: 0.8398
# Epoch 138/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3624 - accuracy: 0.8355
# Epoch 139/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3607 - accuracy: 0.8528
# Epoch 140/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3628 - accuracy: 0.8398
# Epoch 141/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3611 - accuracy: 0.8312
# Epoch 142/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3683 - accuracy: 0.8398
# Epoch 143/150
# 24/24 [==============================] - 0s 998us/step - loss: 0.3707 - accuracy: 0.8312
# Epoch 144/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3571 - accuracy: 0.8442
# Epoch 145/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3622 - accuracy: 0.8398
# Epoch 146/150
# 24/24 [==============================] - 0s 878us/step - loss: 0.3636 - accuracy: 0.8355
# Epoch 147/150
# 24/24 [==============================] - 0s 929us/step - loss: 0.3645 - accuracy: 0.8398
# Epoch 148/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3581 - accuracy: 0.8485
# Epoch 149/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3555 - accuracy: 0.8312
# Epoch 150/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3577 - accuracy: 0.8485
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3487 - accuracy: 0.8398
# Accuracy: 83.98

# %% [markdown]
# ## Challenge 2:
# How can you improve the accuracy to be higher than what you have obtained? (Tune the model or improve the dataset through Feature Engineering)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

scaler.fit(x_test, y_test)

X_train_scaled = scaler.fit_transform(x_test, y_test)
_, accuracy = model.evaluate(x_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3487 - accuracy: 0.8398
# Accuracy: 83.98

# %% [markdown]
# ## Challenge 3:
# How can you save the model and use it again for prediction directly without (re-)training?

# %%
from pickle import dump
dump(model, open('model.pkl', 'wb'))
dump(scaler, open('scaler.pkl', 'wb'))
# Out:
# INFO:tensorflow:Assets written to: ram://74f287a2-fa86-4a5b-af46-be0fd1843319/assets
