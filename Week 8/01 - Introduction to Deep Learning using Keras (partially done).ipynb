# %% [markdown]
# This exercise is adapted from https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/
#
#
# ## Keras Tutorial Overview
#
# There is not a lot of code required, but we are going to step over it slowly so that you will know how to create your own models in the future.
#
# The steps you are going to cover in this tutorial are as follows:
#
# 1. Load Data.
# 2. Define Keras Model.
# 3. Compile Keras Model.
# 4. Fit Keras Model.
# 5. Evaluate Keras Model.
# 6. Tie It All Together.
# 7. Make Predictions
#
# This Keras tutorial has a few requirements:
#
# 1. You have Python 2 or 3 installed and configured.
# 2. You have SciPy (including NumPy) installed and configured.
# 3. You have Keras and a backend (Theano or TensorFlow) installed and configured.

# %% [markdown]
# ### 1. Load Data
# The first step is to define the functions and classes we intend to use in this tutorial.
#
# We will use the NumPy library to load our dataset and we will use two classes from the Keras library to define our model.
#
# The imports required are listed below.

# %%
# first neural network with keras tutorial
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense


import seaborn as sns

sns.set()

# %% [markdown]
# Now load the data from *file pima-indians-diabetes.data.csv* stored in Data folder (check Google Drive if unsure)

# %%
# load the dataset
dataset = loadtxt('..\data\pima-indians-diabetes.data.csv', delimiter=',')

# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %% [markdown]
# **Q:** Find out more about the dataset - such as how many columns, what kind of information does it provide etc.

# %%
import pandas as pd

df = pd.DataFrame(data=dataset)
# df.head()
df.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#                 6           7           8
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# 50%      0.372500   29.000000    0.000000
# 75%      0.626250   41.000000    1.000000
# max      2.420000   81.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       768 non-null    float64
#  1   1       768 non-null    float64
#  2   2       768 non-null    float64
#  3   3       768 non-null    float64
#  4   4       768 non-null    float64
#  5   5       768 non-null    float64
#  6   6       768 non-null    float64
#  7   7       768 non-null    float64
#  8   8       768 non-null    float64
# dtypes: float64(9)
# memory usage: 54.1 KB

# %% [markdown]
# ### 2. Define Keras Model
# Models in Keras are defined as a sequence of layers.
#
# We create a **Sequential model** and add layers one at a time until we are happy with our network architecture.
#
# The first thing to get right is to ensure the input layer has the right number of input features. This can be specified when creating the first layer with the **input_dim** argument and setting it to 8 for the 8 input variables.
#
# *Question:* How do we know the number of layers and their types?
#
# This is a very hard question. There are heuristics that we can use and often the best network structure is found through a process of trial and error experimentation (I explain more about this here). Generally, you need a network large enough to capture the structure of the problem.
#
# In this example, we will use a fully-connected network structure with three layers.
#
# Fully connected layers are defined using the Dense class. We can specify the number of neurons or nodes in the layer as the first argument, and specify the activation function using the activation argument.
#
# We will use the rectified linear unit activation function referred to as ReLU on the first two layers and the Sigmoid function in the output layer.
#
# It used to be the case that Sigmoid and Tanh activation functions were preferred for all layers. These days, better performance is achieved using the ReLU activation function. We use a sigmoid on the output layer to ensure our network output is between 0 and 1 and easy to map to either a probability of class 1 or snap to a hard classification of either class with a default threshold of 0.5.
#
# We can piece it all together by adding each layer:
#
# * The model expects rows of data with 8 variables (the input_dim=8 argument)
# * The first hidden layer has 12 nodes and uses the relu activation function.
# * The second hidden layer has 8 nodes and uses the relu activation function.
# * The output layer has one node and uses the sigmoid activation function.

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### 3. Compile Keras Model
# Now that the model is defined, we can compile it.
#
# Compiling the model uses the efficient numerical libraries under the covers (the so-called backend) such as Theano or TensorFlow. The backend automatically chooses the best way to represent the network for training and making predictions to run on your hardware, such as CPU or GPU or even distributed.
#
# When compiling, we must specify some additional properties required when training the network. Remember training a network means finding the best set of weights to map inputs to outputs in our dataset.
#
# We must specify the loss function to use to evaluate a set of weights, the optimizer is used to search through different weights for the network and any optional metrics we would like to collect and report during training.
#
# In this case, we will use cross entropy as the **loss** argument. This loss is for a binary classification problems and is defined in Keras as **“binary_crossentropy“**.
#
# We will define the optimizer as the efficient stochastic gradient descent algorithm “adam“. This is a popular version of gradient descent because it automatically tunes itself and gives good results in a wide range of problems.
#
# Finally, because it is a classification problem, we will collect and report the classification accuracy, defined via the metrics argument.

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### 4. Fit Keras Model
# We have defined our model and compiled it ready for efficient computation.
#
# Now it is time to execute the model on some data.
#
# We can train or fit our model on our loaded data by calling the fit() function on the model.
#
# Training occurs over epochs and each epoch is split into batches.
#
# * **Epoch:** One pass through all of the rows in the training dataset.
# * **Batch:** One or more samples considered by the model within an epoch before weights are updated.
#
# One epoch is comprised of one or more batches, based on the chosen batch size and the model is fit for many epochs.
#
# The training process will run for a fixed number of iterations through the dataset called epochs, that we must specify using the epochs argument. We must also set the number of dataset rows that are considered before the model weights are updated within each epoch, called the batch size and set using the batch_size argument.
#
# For this problem, we will run for a small number of epochs (150) and use a relatively small batch size of 10.
#
# These configurations can be chosen experimentally by trial and error. We want to train the model enough so that it learns a good (or good enough) mapping of rows of input data to the output classification. The model will always have some error, but the amount of error will level out after some point for a given model configuration. This is called model convergence.

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 2ms/step - loss: 3.4829 - accuracy: 0.4987
# Epoch 2/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.9876 - accuracy: 0.4779
# Epoch 3/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.5156 - accuracy: 0.5130
# Epoch 4/150
# 77/77 [==============================] - 0s 832us/step - loss: 1.3143 - accuracy: 0.5312
# Epoch 5/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.1771 - accuracy: 0.5326
# Epoch 6/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.0829 - accuracy: 0.5521
# Epoch 7/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.9967 - accuracy: 0.5846
# Epoch 8/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.9216 - accuracy: 0.5833
# Epoch 9/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8636 - accuracy: 0.5885
# Epoch 10/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8322 - accuracy: 0.5951
# Epoch 11/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7828 - accuracy: 0.6172
# Epoch 12/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7580 - accuracy: 0.6263
# Epoch 13/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7232 - accuracy: 0.6146
# Epoch 14/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7022 - accuracy: 0.6354
# Epoch 15/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.6289
# Epoch 16/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6642 - accuracy: 0.6380
# Epoch 17/150
# 77/77 [==============================] - 0s 852us/step - loss: 0.6761 - accuracy: 0.6654
# Epoch 18/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.
300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4529 - accuracy: 0.7865
# Epoch 14/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4579 - accuracy: 0.7786
# Epoch 15/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4516 - accuracy: 0.7995
# Epoch 16/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4573 - accuracy: 0.7799
# Epoch 17/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4578 - accuracy: 0.7904
# Epoch 18/300
# 26/26 [==============================] - 0s 814us/step - loss: 0.4506 - accuracy: 0.7826
# Epoch 19/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4511 - accuracy: 0.7956
# Epoch 20/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4473 - accuracy: 0.7969
# Epoch 21/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4528 - accuracy: 0.7878
# Epoch 22/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4482 - accuracy: 0.7917
# Epoch 23/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4506 - accuracy: 0.7917
# Epoch 24/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4454 - accuracy: 0.8034
# Epoch 25/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4507 - accuracy: 0.7982
# Epoch 26/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4503 - accuracy: 0.8021
# Epoch 27/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4458 - accuracy: 0.7852
# Epoch 28/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4500 - accuracy: 0.7982
# Epoch 29/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4465 - accuracy: 0.7995
# Epoch 30/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4427 - accuracy: 0.7956
# Epoch 31/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4463 - accuracy: 0.7982
# Epoch 32/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4497 - accuracy: 0.7839
# Epoch 33/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4460 - accuracy: 0.7904
# Epoch 34/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4456 - accuracy: 0.7982
# Epoch 35/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4493 - accuracy: 0.7930
# Epoch 36/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4433 - accuracy: 0.7969
# Epoch 37/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4464 - accuracy: 0.7956
# Epoch 38/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4534 - accuracy: 0.7865
# Epoch 39/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4472 - accuracy: 0.7839
# Epoch 40/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4427 - accuracy: 0.8034
# Epoch 41/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4467 - accuracy: 0.7878
# Epoch 42/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4449 - accuracy: 0.8021
# Epoch 43/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4468 - accuracy: 0.7878
# Epoch 44/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4452 - accuracy: 0.7917
# Epoch 45/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4464 - accuracy: 0.7852
# Epoch 46/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4441 - accuracy: 0.7956
# Epoch 47/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4482 - accuracy: 0.8021
# Epoch 48/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4515 - accuracy: 0.7917
# Epoch 49/300
# 26/26 [==============================] - 0s 897us/step - loss: 0.4383 - accuracy: 0.7995
# Epoch 50/300
# 26/26 [==============================] - 0s 921us/step - loss: 0.4437 - accuracy: 0.7917
# Epoch 51/300
# 26/26 [==============================] - 0s 823us/step - loss: 0.4409 - accuracy: 0.8034
# Epoch 52/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4432 - accuracy: 0.7969
# Epoch 53/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4506 - accuracy: 0.7930
# Epoch 54/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4500 - accuracy: 0.7826
# Epoch 55/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4425 - accuracy: 0.7943
# Epoch 56/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4498 - accuracy: 0.7956
# Epoch 57/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4418 - accuracy: 0.7891
# Epoch 58/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4387 - accuracy: 0.7995
# Epoch 59/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4407 - accuracy: 0.8021
# Epoch 60/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4428 - accuracy: 0.7943
# Epoch 61/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4427 - accuracy: 0.7995
# Epoch 62/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4415 - accuracy: 0.7943
# Epoch 63/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4491 - accuracy: 0.7839
# Epoch 64/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4421 - accuracy: 0.8021
# Epoch 65/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4417 - accuracy: 0.7891
# Epoch 66/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4448 - accuracy: 0.7982
# Epoch 67/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4423 - accuracy: 0.7904
# Epoch 68/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4417 - accuracy: 0.7904
# Epoch 69/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4400 - accuracy: 0.8073
# Epoch 70/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4584 - accuracy: 0.7878
# Epoch 71/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4456 - accuracy: 0.7982
# Epoch 72/300
# 26/26 [==============================] - 0s 827us/step - loss: 0.4625 - accuracy: 0.7773
# Epoch 73/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4473 - accuracy: 0.7865
# Epoch 74/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4416 - accuracy: 0.7904
# Epoch 75/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4424 - accuracy: 0.7943
# Epoch 76/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4419 - accuracy: 0.7995
# Epoch 77/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4500 - accuracy: 0.7891
# Epoch 78/300
# 26/26 [==============================] - 0s 971us/step - loss: 0.4380 - accuracy: 0.8034
# Epoch 79/300
# 26/26 [==============================] - 0s 948us/step - loss: 0.4484 - accuracy: 0.7982
# Epoch 80/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4381 - accuracy: 0.7943
# Epoch 81/300
# 26/26 [==============================] - 0s 993us/step - loss: 0.4365 - accuracy: 0.7982
# Epoch 82/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4428 - accuracy: 0.7878
# Epoch 83/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4491 - accuracy: 0.7995
# Epoch 84/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4374 - accuracy: 0.7930
# Epoch 85/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4441 - accuracy: 0.7969
# Epoch 86/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4422 - accuracy: 0.8047
# Epoch 87/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4434 - accuracy: 0.8073
# Epoch 88/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4337 - accuracy: 0.8073
# Epoch 89/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4533 - accuracy: 0.7878
# Epoch 90/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4391 - accuracy: 0.7956
# Epoch 91/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4384 - accuracy: 0.7982
# Epoch 92/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4343 - accuracy: 0.7995
# Epoch 93/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4350 - accuracy: 0.8034
# Epoch 94/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4485 - accuracy: 0.8086
# Epoch 95/300
# 26/26 [==============================] - 0s 933us/step - loss: 0.4374 - accuracy: 0.7995
# Epoch 96/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4467 - accuracy: 0.7891
# Epoch 97/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4560 - accuracy: 0.7852
# Epoch 98/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4379 - accuracy: 0
300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4349 - accuracy: 0.8021
# Epoch 161/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4383 - accuracy: 0.8021
# Epoch 162/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4283 - accuracy: 0.7930
# Epoch 163/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4382 - accuracy: 0.7917
# Epoch 164/300
# 26/26 [==============================] - 0s 830us/step - loss: 0.4330 - accuracy: 0.7956
# Epoch 165/300
# 26/26 [==============================] - 0s 880us/step - loss: 0.4386 - accuracy: 0.7982
# Epoch 166/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4307 - accuracy: 0.8047
# Epoch 167/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4302 - accuracy: 0.8125
# Epoch 168/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4296 - accuracy: 0.8099
# Epoch 169/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4315 - accuracy: 0.8060
# Epoch 170/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4344 - accuracy: 0.8125
# Epoch 171/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4323 - accuracy: 0.8034
# Epoch 172/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4466 - accuracy: 0.7826
# Epoch 173/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4407 - accuracy: 0.7956
# Epoch 174/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4342 - accuracy: 0.7982
# Epoch 175/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4326 - accuracy: 0.8008
# Epoch 176/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4276 - accuracy: 0.8099
# Epoch 177/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4551 - accuracy: 0.7865
# Epoch 178/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4434 - accuracy: 0.8008
# Epoch 179/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4416 - accuracy: 0.8047
# Epoch 180/300
# 26/26 [==============================] - 0s 835us/step - loss: 0.4306 - accuracy: 0.8008
# Epoch 181/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4371 - accuracy: 0.8125
# Epoch 182/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4371 - accuracy: 0.7995
# Epoch 183/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4306 - accuracy: 0.8034
# Epoch 184/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4405 - accuracy: 0.8086
# Epoch 185/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4414 - accuracy: 0.7956
# Epoch 186/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4277 - accuracy: 0.8151
# Epoch 187/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4308 - accuracy: 0.8138
# Epoch 188/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4299 - accuracy: 0.8021
# Epoch 189/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4282 - accuracy: 0.8099
# Epoch 190/300
# 26/26 [==============================] - 0s 893us/step - loss: 0.4447 - accuracy: 0.7839
# Epoch 191/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4290 - accuracy: 0.8047
# Epoch 192/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4297 - accuracy: 0.8021
# Epoch 193/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4354 - accuracy: 0.7891
# Epoch 194/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4300 - accuracy: 0.8060
# Epoch 195/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4267 - accuracy: 0.8073
# Epoch 196/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4259 - accuracy: 0.8099
# Epoch 197/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4295 - accuracy: 0.8034
# Epoch 198/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4300 - accuracy: 0.8034
# Epoch 199/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4515 - accuracy: 0.7799
# Epoch 200/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4367 - accuracy: 0.7956
# Epoch 201/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4253 - accuracy: 0.8125
# Epoch 202/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4355 - accuracy: 0.8060
# Epoch 203/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4301 - accuracy: 0.8086
# Epoch 204/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4373 - accuracy: 0.8008
# Epoch 205/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4299 - accuracy: 0.8073
# Epoch 206/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4299 - accuracy: 0.7982
# Epoch 207/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4272 - accuracy: 0.8047
# Epoch 208/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4282 - accuracy: 0.8086
# Epoch 209/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4286 - accuracy: 0.8034
# Epoch 210/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.8034
# Epoch 211/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4395 - accuracy: 0.8008
# Epoch 212/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4328 - accuracy: 0.8008
# Epoch 213/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4335 - accuracy: 0.7917
# Epoch 214/300
# 26/26 [==============================] - 0s 887us/step - loss: 0.4471 - accuracy: 0.7930
# Epoch 215/300
# 26/26 [==============================] - 0s 959us/step - loss: 0.4358 - accuracy: 0.8073
# Epoch 216/300
# 26/26 [==============================] - 0s 865us/step - loss: 0.4253 - accuracy: 0.7995
# Epoch 217/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4285 - accuracy: 0.8151
# Epoch 218/300
# 26/26 [==============================] - 0s 785us/step - loss: 0.4378 - accuracy: 0.7982
# Epoch 219/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4274 - accuracy: 0.8112
# Epoch 220/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4318 - accuracy: 0.8021
# Epoch 221/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4358 - accuracy: 0.7969
# Epoch 222/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4285 - accuracy: 0.8060
# Epoch 223/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4342 - accuracy: 0.8099
# Epoch 224/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4354 - accuracy: 0.7982
# Epoch 225/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4334 - accuracy: 0.8099
# Epoch 226/300
# 26/26 [==============================] - 0s 886us/step - loss: 0.4244 - accuracy: 0.8047
# Epoch 227/300
# 26/26 [==============================] - 0s 904us/step - loss: 0.4296 - accuracy: 0.8060
# Epoch 228/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4242 - accuracy: 0.8034
# Epoch 229/300
# 26/26 [==============================] - 0s 925us/step - loss: 0.4294 - accuracy: 0.8047
# Epoch 230/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4370 - accuracy: 0.8021
# Epoch 231/300
# 26/26 [==============================] - 0s 889us/step - loss: 0.4265 - accuracy: 0.7995
# Epoch 232/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4508 - accuracy: 0.8021
# Epoch 233/300
# 26/26 [==============================] - 0s 896us/step - loss: 0.4364 - accuracy: 0.7969
# Epoch 234/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4358 - accuracy: 0.7995
# Epoch 235/300
# 26/26 [==============================] - 0s 925us/step - loss: 0.4256 - accuracy: 0.8073
# Epoch 236/300
# 26/26 [==============================] - 0s 954us/step - loss: 0.4255 - accuracy: 0.7995
# Epoch 237/300
# 26/26 [==============================] - 0s 942us/step - loss: 0.4375 - accuracy: 0.8008
# Epoch 238/300
# 26/26 [==============================] - 0s 835us/step - loss: 0.4249 - accuracy: 0.8073
# Epoch 239/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4354 - accuracy: 0.8060
# Epoch 240/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4372 - accuracy: 0.7956
# Epoch 241/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4354 - accuracy: 0.7878
# Epoch 242/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4325 - accuracy: 0.7956
# Epoch 243/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4429 - accuracy: 0.7982
# Epoch 244/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4312 - accuracy: 0.8047
# Epoch 245/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4254 - accuracy: 0.8151
# Epoch 246/300
# 26/26 [==============================] - 0s 887us/step - loss: 0.4305 - accuracy: 0.8034
# Epoch 247/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4482 - accuracy: 0.7891
# Epoch 248/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4363 - accuracy: 0.7930
# Epoch 249/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4318 - accuracy: 0.7995
# Epoch 250/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4376 - accuracy: 0.8073
# Epoch 251/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4429 - accuracy: 0.7943
# Epoch 252/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4369 - accuracy: 0.7904
# Epoch 253/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4323 - accuracy: 0.8151
# Epoch 254/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4217 - accuracy: 0.8203
# Epoch 255/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4320 - accuracy: 0.8034
# Epoch 256/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4201 - accuracy: 0.8021
# Epoch 257/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4222 - accuracy: 0.8138
# Epoch 258/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4380 - accuracy: 0.7904
# Epoch 259/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4441 - accuracy: 0.7956
# Epoch 260/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4282 - accuracy: 0.8021
# Epoch 261/300
# 26/26 [==============================] - 0s 975us/step - loss: 0.4269 - accuracy: 0.8112
# Epoch 262/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4259 - accuracy: 0.8073
# Epoch 263/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4322 - accuracy: 0.7930
# Epoch 264/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4332 - accuracy: 0.8138
# Epoch 265/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4198 - accuracy: 0.8060
# Epoch 266/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4313 - accuracy: 0.8112
# Epoch 267/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4356 - accuracy: 0.7969
# Epoch 268/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4348 - accuracy: 0.8008
# Epoch 269/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4320 - accuracy: 0.8047
# Epoch 270/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4228 - accuracy: 0.8138
# Epoch 271/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4348 - accuracy: 0.7917
# Epoch 272/300
# 26/26 [==============================] - 0s 883us/step - loss: 0.4365 - accuracy: 0.7930
# Epoch 273/300
# 26/26 [==============================] - 0s 999us/step - loss: 0.4255 - accuracy: 0.8177
# Epoch 274/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4233 - accuracy: 0.8177
# Epoch 275/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4331 - accuracy: 0.8034
# Epoch 276/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4331 - accuracy: 0.8086
# Epoch 277/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4287 - accuracy: 0.8008
# Epoch 278/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.8164
# Epoch 279/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4438 - accuracy: 0.7943
# Epoch 280/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4317 - accuracy: 0.8112
# Epoch 281/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4305 - accuracy: 0.8164
# Epoch 282/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4280 - accuracy: 0.8177
# Epoch 283/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4278 - accuracy: 0.8021
# Epoch 284/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4314 - accuracy: 0.8060
# Epoch 285/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4496 - accuracy: 0.7852
# Epoch 286/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4265 - accuracy: 0.8047
# Epoch 287/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4380 - accuracy: 0.7956
# Epoch 288/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4248 - accuracy: 0.7917
# Epoch 289/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4199 - accuracy: 0.8151
# Epoch 290/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4347 - accuracy: 0.8008
# Epoch 291/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4269 - accuracy: 0.8034
# Epoch 292/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4293 - accuracy: 0.8008
# Epoch 293/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4283 - accuracy: 0.8008
# Epoch 294/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4269 - accuracy: 0.8086
# Epoch 295/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4352 - accuracy: 0.7956
# Epoch 296/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4230 - accuracy: 0.8086
# Epoch 297/300
# 26/26 [==============================] - 0s 955us/step - loss: 0.4444 - accuracy: 0.7891
# Epoch 298/300
# 26/26 [==============================] - 0s 986us/step - loss: 0.4233 - accuracy: 0.8138
# Epoch 299/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4374 - accuracy: 0.8021
# Epoch 300/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4286 - accuracy: 0.8047

# %% [markdown]
# ### 5. Evaluate Keras Model
# We have trained our neural network on the entire dataset and we can evaluate the performance of the network on the same dataset.
#
# This will only give us an idea of how well we have modeled the dataset (e.g. train accuracy), but no idea of how well the algorithm might perform on new data. We have done this for simplicity, but ideally, you could separate your data into train and test datasets for training and evaluation of your model.
#
# You can evaluate your model on your training dataset using the **evaluate()** function on your model and pass it the same input and output used to train the model.
#
# This will generate a prediction for each input and output pair and collect scores, including the average loss and any metrics you have configured, such as accuracy.
#
# The **evaluate()** function will return a list with two values. The first will be the loss of the model on the dataset and the second will be the accuracy of the model on the dataset. We are only interested in reporting the accuracy, so we will ignore the loss value.

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4251 - accuracy: 0.7969
# Accuracy: 79.69

# %% [markdown]
# ### 7. Make Predictions
# We can adapt the above example and use it to generate predictions on the training dataset, pretending it is a new dataset we have not seen before.
#
# Making predictions is as easy as calling the predict() function on the model. We are using a sigmoid activation function on the output layer, so the predictions will be a probability in the range between 0 and 1. We can easily convert them into a crisp binary prediction for this classification task by rounding them.

# %%
# make probability predictions with the model
predictions = model.predict(X)

# round predictions 
rounded = [round(x[0]) for x in predictions]

# %% [markdown]
# **Q:** now redo predictions by using the function predict_classes(). Show the outcome of the first 10 cases (code provided)

# %%
import numpy as np
classes_x=np.argmax(predictions,axis=1)

for i in range(10):
    print('%s => %d (expected %d)' % (X[i].tolist(), classes_x[i], y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 0 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 0 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 0 (expected 1)
# [5.0, 116.0, 74.0, 0.0, 0.0, 25.6, 0.201, 30.0] => 0 (expected 0)
# [3.0, 78.0, 50.0, 32.0, 88.0, 31.0, 0.248, 26.0] => 0 (expected 1)
# [10.0, 115.0, 0.0, 0.0, 0.0, 35.3, 0.134, 29.0] => 0 (expected 0)
# [2.0, 197.0, 70.0, 45.0, 543.0, 30.5, 0.158, 53.0] => 0 (expected 1)
# [8.0, 125.0, 96.0, 0.0, 0.0, 0.0, 0.232, 54.0] => 0 (expected 1)

# %% [markdown]
# ## Challenge 1:
# Separate the training and test datasets (70% vs 30%) and rerun the evaluation

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y, test_size=0.3)
model.fit(x_test, y_test, epochs=150, batch_size=10)
_, accuracy = model.evaluate(x_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4901 - accuracy: 0.7879
# Epoch 2/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4617 - accuracy: 0.7576
# Epoch 3/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5290 - accuracy: 0.7532
# Epoch 4/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5215 - accuracy: 0.7619
# Epoch 5/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4566 - accuracy: 0.7749
# Epoch 6/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4573 - accuracy: 0.7749
# Epoch 7/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4322 - accuracy: 0.8009
# Epoch 8/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4758 - accuracy: 0.7619
# Epoch 9/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4611 - accuracy: 0.7749
# Epoch 10/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4838 - accuracy: 0.7706
# Epoch 11/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4962 - accuracy: 0.8052
# Epoch 12/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5017 - accuracy: 0.7532
# Epoch 13/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4927 - accuracy: 0.7749
# Epoch 14/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4673 - accuracy: 0.7662
# Epoch 15/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4718 - accuracy: 0.7835
# Epoch 16/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4254 - accuracy: 0.8225
# Epoch 17/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4357 - accuracy: 0.7922
# Epoch 18/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4418 - accuracy: 0.7879
# Epoch 19/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5185 - accuracy: 0.7489
# Epoch 20/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5094 - accuracy: 0.7662
# Epoch 21/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4733 - accuracy: 0.7835
# Epoch 22/150
# 24/24 [==============================] - 0s 947us/step - loss: 0.4273 - accuracy: 0.8052
# Epoch 23/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4378 - accuracy: 0.7965
# Epoch 24/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4662 - accuracy: 0.7749
# Epoch 25/150
# 24/24 [==============================] - 0s 913us/step - loss: 0.5398 - accuracy: 0.7446
# Epoch 26/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4793 - accuracy: 0.8009
# Epoch 27/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4377 - accuracy: 0.8052
# Epoch 28/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4116 - accuracy: 0.8182
# Epoch 29/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4049 - accuracy: 0.8052
# Epoch 30/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4354 - accuracy: 0.8095
# Epoch 31/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4210 - accuracy: 0.7792
# Epoch 32/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4931 - accuracy: 0.7532
# Epoch 33/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4112 - accuracy: 0.8225
# Epoch 34/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4071 - accuracy: 0.8139
# Epoch 35/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4100 - accuracy: 0.8182
# Epoch 36/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4199 - accuracy: 0.7965
# Epoch 37/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4366 - accuracy: 0.8052
# Epoch 38/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4548 - accuracy: 0.7792
# Epoch 39/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4318 - accuracy: 0.7879
# Epoch 40/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4092 - accuracy: 0.8052
# Epoch 41/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4054 - accuracy: 0.8139
# Epoch 42/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5018 - accuracy: 0.7662
# Epoch 43/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4099 - accuracy: 0.8052
# Epoch 44/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4395 - accuracy: 0.8052
# Epoch 45/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4189 - accuracy: 0.8182
# Epoch 46/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4399 - accuracy: 0.7922
# Epoch 47/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4001 - accuracy: 0.8052
# Epoch 48/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4581 - accuracy: 0.8182
# Epoch 49/150
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4069 - accuracy: 0.8268
# Epoch 50/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4098 - accuracy: 0.8009
# Epoch 51/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4156 - accuracy: 0.8095
# Epoch 52/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4233 - accuracy: 0.7792
# Epoch 53/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3992 - accuracy: 0.8182
# Epoch 54/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4080 - accuracy: 0.8052
# Epoch 55/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4382 - accuracy: 0.7835
# Epoch 56/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4033 - accuracy: 0.8398
# Epoch 57/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3888 - accuracy: 0.8312
# Epoch 58/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4166 - accuracy: 0.8312
# Epoch 59/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4048 - accuracy: 0.8355
# Epoch 60/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4190 - accuracy: 0.8052
# Epoch 61/150
# 24/24 [==============================] - 0s 936us/step - loss: 0.4195 - accuracy: 0.8009
# Epoch 62/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3937 - accuracy: 0.8312
# Epoch 63/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4910 - accuracy: 0.7879
# Epoch 64/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3995 - accuracy: 0.8312
# Epoch 65/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3879 - accuracy: 0.8398
# Epoch 66/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5618 - accuracy: 0.7706
# Epoch 67/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4170 - accuracy: 0.7922
# Epoch 68/150
# 24/24 [==============================] - 0s 958us/step - loss: 0.4400 - accuracy: 0.8052
# Epoch 69/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3996 - accuracy: 0.8268
# Epoch 70/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4145 - accuracy: 0.8009
# Epoch 71/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4044 - accuracy: 0.8312
# Epoch 72/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4229 - accuracy: 0.8225
# Epoch 73/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4373 - accuracy: 0.7965
# Epoch 74/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4055 - accuracy: 0.8225
# Epoch 75/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4177 - accuracy: 0.7879
# Epoch 76/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3861 - accuracy: 0.8398
# Epoch 77/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4022 - accuracy: 0.8268
# Epoch 78/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3956 - accuracy: 0.8182
# Epoch 79/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3853 - accuracy: 0.8312
# Epoch 80/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3795 - accuracy: 0.8355
# Epoch 81/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3981 - accuracy: 0.8139
# Epoch 82/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3836 - accuracy: 0.8355
# Epoch 83/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3920 - accuracy: 0.8182
# Epoch 84/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3904 - accuracy: 0.8139
# Epoch 85/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3990 - accuracy: 0.8139
# Epoch 86/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3835 - accuracy: 0.8355
# Epoch 87/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3871 - accuracy: 0.8268
# Epoch 88/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3821 - accuracy: 0.8268
# Epoch 89/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3840 - accuracy: 0.8095
# Epoch 90/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4132 - accuracy: 0.8182
# Epoch 91/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4192 - accuracy: 0.8095
# Epoch 92/150
# 24/24 [==============================] - 0s 997us/step - loss: 0.4086 - accuracy: 0.8095
# Epoch 93/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3990 - accuracy: 0.8095
# Epoch 94/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3759 - accuracy: 0.8442
# Epoch 95/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3841 - accuracy: 0.8139
# Epoch 96/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3859 - accuracy: 0.8355
# Epoch 97/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3762 - accuracy: 0.8312
# Epoch 98/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3785 - accuracy: 0.8312
# Epoch 99/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3960 - accuracy: 0.8139
# Epoch 100/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.8095
# Epoch 101/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3925 - accuracy: 0.7922
# Epoch 102/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3916 - accuracy: 0.8312
# Epoch 103/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3941 - accuracy: 0.8268
# Epoch 104/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3806 - accuracy: 0.8355
# Epoch 105/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3784 - accuracy: 0.8268
# Epoch 106/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3741 - accuracy: 0.8485
# Epoch 107/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3756 - accuracy: 0.8398
# Epoch 108/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3696 - accuracy: 0.8182
# Epoch 109/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3994 - accuracy: 0.8139
# Epoch 110/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3733 - accuracy: 0.8355
# Epoch 111/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3781 - accuracy: 0.8225
# Epoch 112/150
# 24/24 [==============================] - 0s 928us/step - loss: 0.3817 - accuracy: 0.7922
# Epoch 113/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3774 - accuracy: 0.8442
# Epoch 114/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3922 - accuracy: 0.8139
# Epoch 115/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3784 - accuracy: 0.8268
# Epoch 116/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3799 - accuracy: 0.8225
# Epoch 117/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4315 - accuracy: 0.8009
# Epoch 118/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4112 - accuracy: 0.8312
# Epoch 119/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3762 - accuracy: 0.8268
# Epoch 120/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3853 - accuracy: 0.8442
# Epoch 121/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3829 - accuracy: 0.8182
# Epoch 122/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3726 - accuracy: 0.8312
# Epoch 123/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3774 - accuracy: 0.8139
# Epoch 124/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3750 - accuracy: 0.8312
# Epoch 125/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3847 - accuracy: 0.8268
# Epoch 126/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3808 - accuracy: 0.8398
# Epoch 127/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3667 - accuracy: 0.8485
# Epoch 128/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3927 - accuracy: 0.8095
# Epoch 129/150
# 24/24 [==============================] - 0s 984us/step - loss: 0.3734 - accuracy: 0.8268
# Epoch 130/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3798 - accuracy: 0.8442
# Epoch 131/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3625 - accuracy: 0.8485
# Epoch 132/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3697 - accuracy: 0.8528
# Epoch 133/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3785 - accuracy: 0.8182
# Epoch 134/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3614 - accuracy: 0.8398
# Epoch 135/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3677 - accuracy: 0.8485
# Epoch 136/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3625 - accuracy: 0.8225
# Epoch 137/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3649 - accuracy: 0.8442
# Epoch 138/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3647 - accuracy: 0.8355
# Epoch 139/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3719 - accuracy: 0.8095
# Epoch 140/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3667 - accuracy: 0.8528
# Epoch 141/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3960 - accuracy: 0.8095
# Epoch 142/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3655 - accuracy: 0.8355
# Epoch 143/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3720 - accuracy: 0.8225
# Epoch 144/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3785 - accuracy: 0.8398
# Epoch 145/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3737 - accuracy: 0.8182
# Epoch 146/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3784 - accuracy: 0.8355
# Epoch 147/150
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3647 - accuracy: 0.8312
# Epoch 148/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3620 - accuracy: 0.8355
# Epoch 149/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4191 - accuracy: 0.8009
# Epoch 150/150
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4349 - accuracy: 0.7965
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3672 - accuracy: 0.8442
# Accuracy: 84.42

# %% [markdown]
# ## Challenge 2:
# How can you improve the accuracy to be higher than what you have obtained? (Tune the model or improve the dataset through Feature Engineering)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

scaler.fit_transform(x_test, y_test)
_, accuracy = model.evaluate(x_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3672 - accuracy: 0.8442
# Accuracy: 84.42

# %% [markdown]
# ## Challenge 3:
# How can you save the model and use it again for prediction directly without (re-)training?

# %%
from pickle import dump
dump(model, open('model.pkl', 'wb'))
dump(scaler, open('scaler.pkl', 'wb'))
# Out:
# INFO:tensorflow:Assets written to: ram://4d78840a-3650-4466-99d6-f772e0218298/assets
